# %%
import pandas as pd

df1 = pd.DataFrame({
    "id" : [1, 2, 3],
    "customer_id" : [1, 2, 3],
    "customer_name" : ["Rovert","Peter", "Jimmy"]
}, columns = ["id", "customer_id", "customer_name"])

# %%
import pandas as pd
df2 = pd.DataFrame({
    "id" : [1, 2, 4],
    "order_id" : [100, 200, 300],
    "order_date" : ["2025-01-01","2025-06-01", "2025-05-24"]
}, columns = ["id", "order_id", "order_date"])

# %%
# 서로 다른 데이터 프레임을 하나로 합치는 방법

1) concat() : 서로 다른 데이터 프레임을 단순 연결 (*교차되는 특정 인덱스 고려X) -> 좌, 우 & 상, 하 (디폴트)
2) merge() : 특정 인덱스를 기준

# %%
pd.concat([df1, df2])
# Out:
#    id  customer_id customer_name  order_id
# 0   1          1.0        Rovert       NaN
# 1   2          2.0         Peter       NaN
# 2   3          3.0         Jimmy       NaN
# 0   1          NaN           NaN     100.0
# 1   2          NaN           NaN     200.0
# 2   4          NaN           NaN     300.0

# %%
doc = pd.concat([df1, df2], axis=1)
doc
# Out:
#    id  customer_id customer_name  id  order_id customer_name
# 0   1            1        Rovert   1       100           NaN
# 1   2            2         Peter   2       200           NaN
# 2   3            3         Jimmy   4       300           NaN

# %%
pd.merge(df1, df2) # merge() => inner JOIN과 유사
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1            1        Rovert       100  2025-01-01
# 1   2            2         Peter       200  2025-06-01

# %%
pd.merge(df1,df2, on="id")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1            1        Rovert       100  2025-01-01
# 1   2            2         Peter       200  2025-06-01

# %%
pd.merge(df1, df2, on="id", how="outer")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1          1.0        Rovert     100.0  2025-01-01
# 1   2          2.0         Peter     200.0  2025-06-01
# 2   3          3.0         Jimmy       NaN         NaN
# 3   4          NaN           NaN     300.0  2025-05-24

# %%
pd.merge(df1, df2, on="id", how="left")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1            1        Rovert     100.0  2025-01-01
# 1   2            2         Peter     200.0  2025-06-01
# 2   3            3         Jimmy       NaN         NaN

# %%
pd.merge(df1, df2, on="id", how="right")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1          1.0        Rovert       100  2025-01-01
# 1   2          2.0         Peter       200  2025-06-01
# 2   4          NaN           NaN       300  2025-05-24

# %%
df1 = df1.set_index("id")
df1
# Out:
#     customer_id customer_name
# id
# 1             1        Rovert
# 2             2         Peter
# 3             3         Jimmy

# %%
df2 = df2.set_index("id")
df2
# Out:
#     order_id  order_date
# id
# 1        100  2025-01-01
# 2        200  2025-06-01
# 4        300  2025-05-24

# %%
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1             1        Rovert       100  2025-01-01
# 2             2         Peter       200  2025-06-01

# %%
pd.merge(df1, df2, how="outer", left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1           1.0        Rovert     100.0  2025-01-01
# 2           2.0         Peter     200.0  2025-06-01
# 3           3.0         Jimmy       NaN         NaN
# 4           NaN           NaN     300.0  2025-05-24

# %%
pd.merge(df1, df2, how="left", left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1             1        Rovert     100.0  2025-01-01
# 2             2         Peter     200.0  2025-06-01
# 3             3         Jimmy       NaN         NaN

# %%
pd.merge(df1, df2, how="right", left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1           1.0        Rovert       100  2025-01-01
# 2           2.0         Peter       200  2025-06-01
# 4           NaN           NaN       300  2025-05-24

# %%
df = pd.DataFrame({
    "영어": [60, 70],
    "수학": [100, 50],
    "국어": [50, 80]
}, columns=["영어", "수학"], index=["Jimmy", "jim"])
df
# Out:
#        영어   수학
# Jimmy  60  100
# jim    70   50

# %%
# def func(df_data) :
#     print(type(df_data))
#     print(df_data.index)
#     print(df_data.values)
def func(df_data) :
    df_data["영어"] = 80
    return df_data

# %%
df_func = df.apply(func, axis=1)

# %%
df_func = df.apply(func, axis=0)

# %%
df_func

# %%
df = pd.DataFrame({
    "성별" : ["남","남","남"],
    "이름" : ["David","jimmy","jim"],
    "수학" : [100,50,80],
    "국어" : [80,70,50]
})
# Out:
#   성별     이름   수학  국어
# 0  남  David  100  80
# 1  남  jimmy   50  70
# 2  남    jim   80  50

# %%
selected_columns = ["이름", "수학", "국어"]

df = df[selected_columns]
df.groupby("이름").sum()
# Out:
#         수학  국어
# 이름
# David  100  80
# jim     80  50
# jimmy   50  70

# %%
import os

PATH = "COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports/"
file_list, csv_list = os.listdir(PATH), list()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 4
#       1 import os
#       3 PATH = "COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports/"
# ----> 4 file_list = os.listdir(PATH)
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports/'
