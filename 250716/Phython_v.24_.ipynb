# %%
mission => 공공데이터포털 사이트 > 캠핑장 정보 api 찾아옵니다
100개의 캠핑장 정보만 엑셀에 저장
num 값, 캠핑장 콘텐츠id 값, 캠핑장 이름, 위치, 주소, 홈페이지

# %%
import requests
import json
import openpyxl

public_open_api = "https://api.odcloud.kr/api/15004303/v1/uddi:398988c5-5a01-4445-b093-cbe6578456b8?page=1&perPage=10&serviceKey=oMLY3SekqYi6Z3IHiIY01u%2F5BYoy8D0%2Foxwm0wq%2BUI8u3qqZwutT5AuBlmd3bTIjc22dXkLGnEAjYKI2y2hRaQ%3D%3D&_returnType=JSON"
res = requests.get(public_open_api)

for o in res.
    
print(res.get_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       5 public_open_api = "https://api.odcloud.kr/api/15004303/v1/uddi:398988c5-5a01-4445-b093-cbe6578456b8?page=1&perPage=10&serviceKey=oMLY3SekqYi6Z3IHiIY01u%2F5BYoy8D0%2Foxwm0wq%2BUI8u3qqZwutT5AuBlmd3bTIjc22dXkLGnEAjYKI2y2hRaQ%3D%3D&_returnType=JSON"
#       6 res = requests.get(public_open_api)
# ---> 10 print(res.get_text)
#
# AttributeError: 'Response' object has no attribute 'get_text'
