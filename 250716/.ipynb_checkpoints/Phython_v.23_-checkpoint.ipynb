# %%
import requests
import openpyxl

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["D"].width = 150
excel_sheet.append(["num","release_date", "title", "overview", "vote_average"])

url_base = "https://api.themoviedb.org/3/movie/now_playing"


headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2MDg1N2RjOTg5MDIxZDViMDUzNmE2ZGI2Y2JmMDE2ZCIsIm5iZiI6MTc1MjE5MjI0MS43OTIsInN1YiI6IjY4NzA1NGYxNTRkYzk4ODc0YWJhMjkxMyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XeqNn3by7mTub_UjSDhUt_8OQEJUgTfVIXVWUkATv14"
}


num, page = 0, 1

for index in range(1,6) :
    url = f"{url_base}?language=ko-KR&page={page}"
    res = requests.get(url, headers=headers)
    
    if res.status_code == 200 :
        data = res.json()
        for item in data["results"] :
            num += 1
            if num > 100 :
                break
            excel_sheet.append([num, item["release_date"], item["title"], item["overview"], item["vote_average"]])
        page += 1
excel_file.save("Movie_250715.xlsx")
excel_file.close()
