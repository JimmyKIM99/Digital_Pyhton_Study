# %%
import json



data = """
{
    "id":"01", "language":"python", "edition":"third", "author":"David",
    "history":
        [
            {
                "date":"2025-07-16",
                "item":"iPhone"
            },
            {
                "date":"2025-03-11",
                "item":"Adorid"
            }
        ]
}
"""

json_data = json.loads(data)
print(json_data["history"][0]["date"])
# Out:
# 2025-07-16

# %%
import json

data = """
{
    "lastBuildDate": "Wed, 16 Jul 2025 13:20:08 +0900",
    "total": 1261632,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "[비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2",
            "link": "https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5038779/50387791565.jpg",
            "lprice": "41900",
            "hprice": "",
            "mallName": "무신사",
            "productId": "50387791565",
            "productType": "2",
            "brand": "비비앙",
            "maker": "",
            "category1": "화장품/미용",
            "category2": "향수",
            "category3": "여성향수",
            "category4": ""
        },
        {
            "title": "[토앤토] x 로우클래식 플립플랍 Zerovity 크림 Z-FF-LCCR",
            "link": "https://link.musinsa.com/app/goods/3320672?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_4788542/47885429385.jpg",
            "lprice": "88000",
            "hprice": "",
            "mallName": "무신사",
            "productId": "47885429385",
            "productType": "2",
            "brand": "토앤토",
            "maker": "",
            "category1": "패션잡화",
            "category2": "여성신발",
            "category3": "슬리퍼",
            "category4": ""
        }
    ]
}
"""
json_data = json.loads(data)
print(json_data["items"][0]["title"])
# Out:
# [비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2

# %%
import requests
import json
import pprint
import openpyxl

client_id = "22eRGRqfPdwzBFL9hbmc"
client_secret = "75fN7Kc_oY"
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크"])

for index in range(10) :
    start_number = start + (index * 100)
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=무신사&display=100&start=" + str(start_number)
    header_parans = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_parans)
    
    if res.status_code == 200 :
        data = res.json()
        #pprint.pprint(data)
        #print(data)
        for  item in data["items"] :
            num += 1
            excel_sheet.append([num, item["title"], item["link"]])
            print(num, item["title"], item["link"])
            
    else :
        print("Error Code", res.status_code)


excel_file.save("shopping_with_무신사.xlsx")
excel_file.close()
# Out:
# 1 [비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2 https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 2 [보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 3 [피지컬가먼츠] P2407 메쉬배색 기능성 오버핏반팔 [블랙] P2407 https://link.musinsa.com/app/goods/4128907?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 4 [마뗑킴] ACCORDION MINI BAG IN SILVER MK2400BG730MSV https://link.musinsa.com/app/goods/3024801?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 5 [토앤토] x 로우클래식 플립플랍 Zerovity 크림 Z-FF-LCCR https://link.musinsa.com/app/goods/3320672?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# ...

# %%
import requests
import json
import pprint
import openpyxl

client_id = "22eRGRqfPdwzBFL9hbmc"
client_secret = "75fN7Kc_oY"
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 100
excel_sheet.column_dimensions["C"].width = 100
excel_sheet.append(["No", "제목", "링크"])

for index in range(10) :
    start_number = start + (index * 100)
    naver_open_api = "https://openapi.naver.com/v1/search/news.json?query=트럼프&display=100&start=" + str(start_number)
    header_parans = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_parans)
    
    if res.status_code == 200 :
        data = res.json()
        #pprint.pprint(data)
#        print(data)
#        for  item in data["items"] :
#            num += 1
#            excel_sheet.append([num, item["title"], item["link"]])
#            print(num, item["title"], item["link"])
#            
#    else :
#        print("Error Code", res.status_code)


# excel_file.save("shopping_with_트럼프.xlsx")
# excel_file.close()
# Out:
# {'lastBuildDate': 'Wed, 16 Jul 2025 15:26:09 +0900', 'total': 2039675, 'start': 1, 'display': 100, 'items': [{'title': "[서해평화 가능한가⑥] 미국 '중국 압박' 동아시아 전략의 한복판 서해", 'originallink': 'https://www.incheontoday.com/news/articleView.html?idxno=305420', 'link': 'https://www.incheontoday.com/news/articleView.html?idxno=305420', 'description': "인천투데이=김갑봉·인투아이(INTO-AI) 기자 | <b>트럼프</b> 2기 행정부가 출범한 지 약 6개월이 지났다. 예상대로... <b>트럼프</b>, &quot;한국은 머니머신&quot;... 방위비 폭탄의 실체 <b>트럼프</b>는 당선 전부터 한국을 '머니머신... ", 'pubDate': 'Wed, 16 Jul 2025 15:24:00 +0900'}, {'title': "소고기·투자·방위비까지 美요구 쌓여…'<b>트럼프</b> 설득' 해법찾기(종합)", 'originallink': 'https://www.yna.co.kr/view/AKR20250716084151003?input=1195m', 'link': 'https://n.news.naver.com/mnews/article/001/0015511162?sid=101', 'description': "美 '3대 요구' 농산물·디지털·자동차…'<b>트럼프</b> 관심' 알래스카 LNG까지 16일 통상 소식통들에 따르면 관세... 농민들은 미국의 러스트 벨트 노동자 계층과 더불어 <b>트럼프</b> 대통령이 중요하게 여기는 지지층인 만큼, 미국... ", 'pubDate': 'Wed, 16 Jul 2025 15:22:00 +0900'}, {'title': "엔비디아 'H20' 판매 재개에 中 데이터센터 주가 급등세
# ...

# %%
import requests
import json
import openpyxl


client_id = "22eRGRqfPdwzBFL9hbmc"
client_secret = "75fN7Kc_oY"
start, num = 0, 1

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width = 70
excel_sheet.column_dimensions["C"].width = 150
excel_sheet.append(["No", "제목", "내용","업데이트 날짜"])

for index in range(10) :
    start_number = start + (index*100)
    naver_open_api = "https://openapi.naver.com/v1/search/news.json?query=트럼프&display=100&start=" + str(start_number)
    header_parans = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_parans)

    if res.status_code == 200 :
        data = res.json()
#        print(data)
        for item in data ["items"] :
            num += 1
            excel_sheet.append([num, item["title"], item["description"], item["pubDate"]])
        else : 
            print("Error Code", res.status_code)
excel_file.save("News_with_트럼프.xlsx")
excel_file.close()
# Out:
# {'lastBuildDate': 'Wed, 16 Jul 2025 15:42:19 +0900', 'total': 2039693, 'start': 100, 'display': 100, 'items': [{'title': "'엡스타인 파일' 놓고 미 공화당 균열…&quot;투명하게 공개해야&quot;", 'originallink': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008179725&plink=ORI&cooper=NAVER', 'link': 'https://n.news.naver.com/mnews/article/055/0001275741?sid=104', 'description': "▲ 마이크 존슨 미 하원의장 미국에서 이른바 '엡스타인 파일' 논란에 도널드 <b>트럼프</b> 대통령 지지자들이 진상... 최근 <b>트럼프</b> 행정부는 엡스타인의 사망과 관련된 추가 정보를 공개하지 않겠다고 밝혔습니다. 하지만 당국의... ", 'pubDate': 'Wed, 16 Jul 2025 14:40:00 +0900'}, {'title': '[S리포트] ②CBDC에 힘주는 중국, 미국 견제 가능할까', 'originallink': 'https://www.moneys.co.kr/article/2025071606532842137', 'link': 'https://n.news.naver.com/mnews/article/417/0001089616?sid=101', 'description': '하지만 <b>트럼프</b> 2기 행정부의 강력한 견제와 구조적 한계로 중국의 승부수가 글로벌 화폐 질서를... <b>트럼프</b> 2기, CBDC 봉쇄로 중국 견제 나서 이 같은 흐름에도 중국의 디지털 위안화가 단기간 내에 미국 달러 패권을... ', 'pubDate': 'Wed, 16 Jul 2025 14:40:00 +0900'}, {'title': '<b>트럼프</b>, 인플레 압박에도 관세 폭탄 투하 준비…“이달 말 의약품 관세.
# ...

# %%
import requests
import json
import openpyxl

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["A"].width = 25
excel_sheet.column_dimensions["B"].width = 25
excel_sheet.column_dimensions["C"].width = 150
excel_sheet.column_dimensions["D"].width = 20
excel_sheet.append(["original_title", "title", "overview", "vote_average"])
header01 = "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2MDg1N2RjOTg5MDIxZDViMDUzNmE2ZGI2Y2JmMDE2ZCIsIm5iZiI6MTc1MjE5MjI0MS43OTIsInN1YiI6IjY4NzA1NGYxNTRkYzk4ODc0YWJhMjkxMyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.XeqNn3by7mTub_UjSDhUt_8OQEJUgTfVIXVWUkATv14"
header02 = "application/json"


tmdb_open_api = "https://api.themoviedb.org/3/movie/now_playing?language=ko-KR&page=1"
header_parans = {"Authorization":header01, "accept":header02}
res = requests.get(tmdb_open_api, headers=header_parans)

if res.status_code == 200 :
    data = res.json()
    for item in data ["results"] :
        excel_sheet.append([item["original_title"], item["title"], item["overview"], item["vote_average"]])
    
else : 
    print("Error Code", res.status_code)

#들여쓰기 중요!!

excel_file.save("TMDB_movie.xlsx")
excel_file.close()
