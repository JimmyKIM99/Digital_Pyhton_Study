# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument('--headless')
# options.add_argument('--disable-gpu')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
# options.add_argument('--user-Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.musinsa.com/main/musinsa/recommend?gf=A")
time.sleep(3)

search_button = driver.find_element(By.CSS_SELECTOR, ".sc-dzagxs-2")
search_button.click()
time.sleep(2)
popular_keywords = driver.find_elements(By.CSS_SELECTOR, ".search-home-popular-wrap .sc-1xzm8bl-1")
target_keyword = popular_keywords[1].text
print("목표키워드 : ", target_keyword)

search_input = driver.find_element(By.CLASS_NAME, "search-home-search-bar-keyword")
search_input.clear()
search_input.send_keys(target_keyword)
time.sleep(1)

search_input.send_keys(Keys.RETURN)
time.sleep(5)

print("탐색완료 : ", driver.title)
driver.quit()
# Out:
# 목표키워드 :  반팔
# 탐색완료 :  반팔 | 무신사 추천 상품

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import re 

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument('--headless')
# options.add_argument('--disable-gpu')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
#options.add_argument('--user-Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.musinsa.com/main/musinsa/recommend?gf=A")
time.sleep(3)

search_button = driver.find_element(By.CSS_SELECTOR, ".sc-dzagxs-2")
search_button.click()
time.sleep(2)
popular_keywords = driver.find_elements(By.CSS_SELECTOR, ".search-home-popular-wrap .sc-1xzm8bl-1")
target_keyword = popular_keywords[1].text
print("목표키워드 : ", target_keyword)

search_input = driver.find_element(By.CLASS_NAME, "search-home-search-bar-keyword")
search_input.clear()
search_input.send_keys(target_keyword)
time.sleep(1)

search_input.send_keys(Keys.RETURN)
time.sleep(5)

print("탐색완료 : ", driver.title)

scroll_pause = 2

for _ in range(10) :
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause)

products = driver.find_elements(By.CSS_SELECTOR, "div.sc-d36st-1.elXjMR")[:100]
product_data = []

for product in products :
    try :
        name = product.find_element(By.CSS_SELECTOR, "div.sc-cMuefe.jIlLeV a.gtm-select-item span").text.strip()
        # print(name)
        url = product.find_element(By.CSS_SELECTOR, "div.sc-cMuefe.jIlLeV a.gtm-select-item").get_attribute("href")
        # print(url)
        review_info = product.find_elements(By.CSS_SELECTOR, "span.text-etc_11px_reg.text-yellow.font-pretendard")[1].text.strip()
        # print(review_info)
        review_elements = product.find_elements(By.CSS_SELECTOR, "span.text-etc_11px_reg.text-yellow.font-pretendard")
        review_info = review_elements[1].text if len(review_elements) > 1 else ""
        review_count = int(re.sub(r"[^\d]", "", review_info)) if review_info else 0
        product_data.append({"상품명": name, "링크": url, "리뷰수": review_count})
        
        
    except :
        continue

df = pd.DataFrame(product_data)
df_top30 = df.sort_values(by="리뷰수", ascending=False).head(30).reset_index(drop=True)
            
driver.quit()
print(df_top30.head())
# Out:
# 목표키워드 :  반팔
# 탐색완료 :  반팔 | 무신사 추천 상품
#                                   상품명  \
# 0      PLUR SS TEE WHITE(CV2BMMT515A)
# 1                    오리엔탈 워크샵 반팔티 화이트
# 2                        세일링 요트클럽 티셔츠
# 3  XTT091 미누의 트라이벌 스포티 반팔 티셔츠 (BLACK)
# 4              CANDY STRIPE T / BLACK
#
#                                          링크  리뷰수
# 0  https://www.musinsa.com/products/1849317  934
# 1  https://www.musinsa.com/products/3182406  865
# 2  https://www.musinsa.com/products/4065364  817
# 3  https://www.musinsa.com/products/3890825  751
# 4  https://www.musinsa.com/products/4142537  740

# %%
from openpyxl import Workbook

driver = webdriver.Chrome(service=service, options=options)
all_reviews = []
for idx, row in df_top30.iterrows() :
    print(f"{idx+1}번째 상품리뷰 수집 중 :", {row['상품명']})
    driver.get(row['링크'])
    time.sleep(2)

    try :
        driver.execute_script("window.scrollBy(0, 200);")
        time.sleep(1)
        review_button = driver.find_element(By.XPATH, "//button[@data-button-id='prd_review_tab']")
        review_button.click()
        time.sleep(2)
        for _ in range(2) :
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(1.5)
        review_elements = driver.find_elements(By.CSS_SELECTOR,".text-body_13px_reg.text-black.font-pretendard")
        for review in review_elements[:10] :
            text = review.text.strip()
            if text :
                all_reviews.append({
                    "상품명" : row["상품명"],
                    "리뷰" : text
                })
    except Exception as e :
        print("리뷰 수집 실패 : ", e)
        continue
driver.quit()

wb = Workbook()
ws = wb.active
ws.title = "무신사리뷰"

ws.append(["상품명", "리뷰"])

for r in all_reviews :
    ws.append([r["상품명"], r["리뷰"]])

wb.save("musinsa_top30_reviews.xlsx")
print("엑셀 저장 완료")
# Out:
# 1번째 상품리뷰 수집 중 : {'PLUR SS TEE WHITE(CV2BMMT515A)'}
# 2번째 상품리뷰 수집 중 : {'오리엔탈 워크샵 반팔티 화이트'}
# 3번째 상품리뷰 수집 중 : {'세일링 요트클럽 티셔츠'}
# 4번째 상품리뷰 수집 중 : {'XTT091 미누의 트라이벌 스포티 반팔 티셔츠 (BLACK)'}
# 5번째 상품리뷰 수집 중 : {'CANDY STRIPE T / BLACK'}
# 6번째 상품리뷰 수집 중 : {'썬 레트로 그래픽 반팔 티셔츠 레트로 차콜'}
# 7번째 상품리뷰 수집 중 : {'노미네이츠 피그먼트 반팔티셔츠 딥그레이 SHST6789'}
# 8번째 상품리뷰 수집 중 : {'ship t-shirt(white)'}
# 9번째 상품리뷰 수집 중 : {'[한소희 착용] 미니핏 그래픽 티셔츠 395504 [21color]'}
# 10번째 상품리뷰 수집 중 : {'C 90S LINE BASIC T-SHIRT_NAVY'}
# 11번째 상품리뷰 수집 중 : {'ML GARMENTS CREW [PIGMENT D.GREY]'}
# 12번째 상품리뷰 수집 중 : {'로고 배색 져지 [블랙]'}
# 13번째 상품리뷰 수집 중 : {'[2PACK] 어센틱 로고 반팔티셔츠'}
# 14번째 상품리뷰 수집 중 : {'DOODLE HEART RINGER HALF T WHITE'}
# 15번째 상품리뷰 수집 중 : {'슬림 뱃지 립 티셔츠 (T32E1TTO06TWT1YBR)'}
# 16번째 상품리뷰 수집 중 : {'트래블 티셔츠 블랙'}
# 17번째 상품리뷰 수집 중 : {'VSW Cartoon 1 T-Shirts White'}
# 18번째 상품리뷰 수집 중 : {'[2PACK] 아치로고 오버사이즈 반팔 티셔츠_4컬러'}
# 19번째 상품리뷰 수집 중 : {'Digital Tattoo Tee Renewal Mint'}
# 20번째 상품리뷰 수집 중 : {'아치로고 오버사이즈 반팔 티셔츠 [차콜]'}
# 21번째 상품리뷰 수집 중 : {'set 89 t (dark grey)'}
# 22번째 상품리뷰 수집 중 : {'DOUBLE LACE S/S TEE(BROWN)'}
# 23번째 상품리뷰 수집 중 : {'[2PACK] 쿨링 헨리넥 반팔 T_(4COLOR)'}
# 24번째 상품리뷰 수집 중 : {'여성) 포인텔 스쿱넥 반팔 티_MSF2TS2053'}
# 25번째 상품리뷰 수집 중 : {'Cross Angel 슬림핏 반팔티'}
# 26번째 상품리뷰 수집 중 : {'PATTERN LOGO BASIC FIT T SHIRT WHITE NAVY'}
# 27번째 상품리뷰 수집 중 : {'PIT A PAT T-SHIRT_BROWN'}
# 28번째 상품리뷰 수집 중 : {'[힛지스 착용] 베티붑 하트 버스트 오버핏 반팔티_레드'}
# 29번째 상품리뷰 수집 중 : {'NO-VISION 반팔티셔츠 (블랙)'}
# 30번째 상품리뷰 수집 중 : {'블러 이펙트 라운드 티셔츠-5Color'}
# 엑셀 저장 완료

# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\sagej\anaconda3\lib\site-packages (2.0.39)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sagej\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sagej\anaconda3\lib\site-packages (from sqlalchemy) (4.14.1)

# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus


EXCEL_PATH = "musinsa_top30_reviews.xlsx"
DB_NAME = "musinsa_db_v4"
TABLE_NAME = "reviews"
USER = "root"
PASSWORD = "@!Dydwls900"
ENCODED_PASSWORD = quote_plus(PASSWORD)
HOST = "127.0.0.1"
PORT = 3306

df = pd.read_excel(EXCEL_PATH)
conn = pymysql.connect(host=HOST, user=USER, password=PASSWORD, port=PORT)
cursor = conn.cursor()
cursor.execute(
    f"CREATE DATABASE IF NOT EXISTS {DB_NAME} CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;"
)
conn.close()

engine_str = f"mysql+pymysql://{USER}:{ENCODED_PASSWORD}@{HOST}:{PORT}/{DB_NAME}?charset=utf8mb4"
engine = create_engine(engine_str)

df.to_sql(name=TABLE_NAME, con=engine, if_exists="replace", index=False)
print(f"데이터가 MySQL {DB_NAME}의 테이블 {TABLE_NAME}에 성공적으로 저장되었습니다.")
# Out:
# 데이터가 MySQL musinsa_db_v4의 테이블 reviews에 성공적으로 저장되었습니다.

# %%
pip install gspread # 파이썬에서 구글 스프레드시터에 접근 가능
# Out:
# Collecting gspread
#   Downloading gspread-6.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting google-auth>=1.12.0 (from gspread)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib>=0.4.1 (from gspread)
#   Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sagej\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sagej\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.12.0->gspread)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sagej\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.12.0->gspread) (0.4.8)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.4.1->gspread)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sagej\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sagej\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sagej\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sagej\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sagej\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2025.7.14)
# Downloading gspread-6.2.1-py3-none-any.whl (59 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: rsa, oauthlib, requests-oauthlib, google-auth, google-auth-oauthlib, gspread
#
#    ------------- -------------------------- 2/6 [requests-oauthlib]
#    --------------------------------- ------ 5/6 [gspread]
#    ---------------------------------------- 6/6 [gspread]
#
# Successfully installed google-auth-2.40.3 google-auth-oauthlib-1.2.2 gspread-6.2.1 oauthlib-3.3.1 requests-oauthlib-2.0.0 rsa-4.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install oauth2client # 구글 접속 허가
# Out:
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting httplib2>=0.9.1 (from oauth2client)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\sagej\anaconda3\lib\site-packages (from oauth2client) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\sagej\anaconda3\lib\site-packages (from oauth2client) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\sagej\anaconda3\lib\site-packages (from oauth2client) (4.9.1)
# Requirement already satisfied: six>=1.6.1 in c:\users\sagej\anaconda3\lib\site-packages (from oauth2client) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sagej\anaconda3\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Installing collected packages: httplib2, oauth2client
#
#    ---------------------------------------- 2/2 [oauth2client]
#
# Successfully installed httplib2-0.22.0 oauth2client-4.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from konlpy.tag import Okt
from oauth2client.service_account import ServiceAccountCredentials
import gspread
import pandas as pd

df = pd.read_excel("musinsa_top30_reviews.xlsx")

okt = Okt()
df["리뷰_키워드"] = df["리뷰"].apply(lambda x: ", ".join(okt.nouns(str(x))))

scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("airy-cortex-468703-a0-155e0b07221d.json", scope)
client = gspread.authorize(creds)

spreadsheet = client.open("무신사_리뷰_분석_v.01")
sheet1 = spreadsheet.sheet1
sheet1.clear()
sheet1.update([df.columns.values.tolist()] + df.values.tolist())

try :
    spreadsheet.add_worksheet(title="키워드 분석", rows="1000", cols="20")
except :
    pass

sheet2 = spreadsheet.worksheet("키워드 분석")
sheet2.clear()
sheet2.update([["상품명", "리뷰", "리뷰_키워드"]] + df[["상품명", "리뷰", "리뷰_키워드"]].values.tolist())

print("구글 스프레듯트에 원본 + 키워드 분석자료 업데이트 완료")
# Out:
# 구글 스프레듯트에 원본 + 키워드 분석자료 업데이트 완료
