# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com/accounts/login/")
print("수동으로 인증 시작!")
time.sleep(30)

with open("instagram_cookies.pkl", "wb") as f :
    pickle.dump(driver.get_cookies(), f)
print("쿠키 저장 완료")
driver.quit()


# cookie, wb 형태로 저장
# Out:
# 수동으로 인증 시작!
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com/")
with open("instagram_cookies.pkl", "rb") as f :
    cookies = pickle.load(f)
for cookie in cookies :
    driver.add_cookie(cookie)

driver.refresh()
time.sleep(5)

try :
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)
except :
    pass

keyword = "미술관"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try :
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url" : url, "caption" : caption})
    except Exception as e :
        print(f"캡션 추출을 실패 : {url} | {e}")
        continue

driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DLD_b55zJ3t/
# Photo shared by 채보미 도슨트 | 미술교육자 on June 18, 2025 tagging @bom_docent. 상의 및 문구: '전시추천예술미술 예술미술 미술 전시 전시추천 추천 예술 2025 한국인이라면 꼭 봐야 하는 한국 미술 전시 Top.14 예술로봄 @bom_docent'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DK8jHaMPK9_/
# Photo by 데이오프 l 전시•팝업•디자인•공간 on June 15, 2025. 포스터 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMWuNAQMtDP/
# Photo shared by 컨트롤에스 매거진 | Control S magazine on July 20, 2025 tagging @00_dy_artist. 문구: 'cantrol Cantral&Magazine Magazina D 꾸욱~ 미술관 이렇게 즐겨봐 디자인과가 미슬관 즐기는 디자인과가미술관즐기는법 법'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLluXShBJGH/
# Photo by 캐치업 소스🥫ㅣ패션 라이프스타일 커뮤니티 on July 01, 2025. 문구: 'PLACE Catchup S c 10 공짜로 교양 쌓자 무료 전시·공간 7선'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKt2PZev30x/
# Photo shared by 널 위한 문화예술 on June 10, 2025 tagging @seoulmuseumofart. 사람 1명 및 문구: '時華 HS 网 u NOG 서울에 서울에들어선 들어선 이 신상 신상미술관 미술관 꼭 가야하는 이유5 5'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLmUfioogwN/
# Photo shared by 골든걸 | 공연•전시•문화 매거진 on July 02, 2025 tagging @sejong_museum_of_art, and @monet_to_warhol. 포스터 및 문구: '모네에서 맨디미을까지 세종문화회관 요하네스버그 아트 갤러리 미술관 특별전 monet to warhol om the he Johannesburg Mastepicesiontedeb Art Gallery EVENT 143점의 명화로 만나는 서양 미 미술사 400년 <모네에서 앤디워홀까지> 25. 05. 16. 25. 08. 31.'의 일러스트레이션일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMVTD8Cx-u9/
# Photo shared by Artscoop 아트스쿱 on July 20, 2025 tagging @kgu_artmanagement, and @kgu_a_with. 사람 3명 및 문구: 'Is 경기, 경기,한스쿱 한 스쿱 고3 주목! 큐레이터가 되고싶은 너를 위해 경기대학교 Fine 학부 미술경영전공'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKjpAcXS_VY/
# Photo shared by ARTART 아트아트 on June 06, 2025 tagging @park_looking. 사람 1명 및 문구: 'ARTART 출처: l:tomsachs_ddp 盟の 品 -- ពកា 6월 꼭 가봐야 할 서울 전시 ZIP.'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMrhmMBSoze/
# Photo by 𝗔𝗥𝗧 𝗠𝗨𝗦𝗘𝗨𝗠 𝗩𝗘𝗥𝗦𝗜 벗이미술관 on July 28, 2025. 사람 3명, 앞치마 및 문구: 'VERSI& ကနီ ART CLASS'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DIbHqBzsrVh/
# Photo by OOA 오에이 on April 14, 2025. 사진 설명이 없습니다..
# ============================================================
