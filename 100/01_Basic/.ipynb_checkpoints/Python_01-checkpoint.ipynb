# %%
### 1. 네이버 뉴스에서 "디지털 마케팅" 키워드로 검색한 뉴스 제목 10개를 수집

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
driver.get("https://news.naver.com/")

element = driver.find_element(By.XPATH, "//span[@class='Nicon_search']")
element.click()
element1 = driver.find_element(By.XPATH, "//input[@type='search']")
element1.click()
element1.send_keys("디지털 마케팅")
element1.send_keys(Keys.RETURN)
time.sleep(2)

title_list = []
elements = driver.find_elements(By.XPATH, "//ul[@class='list_news _infinite_list']")
time.sleep(2)
#for element2 in elements[:10] :
#    title = element2.get_attribute("span")
#    title_list.append(title.text.strip())
print(elements)

driver.quit()
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

query = "디지털 마케팅"
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={query}"

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("a.ox1N67gcMkHhMh7hbfHi")
for i, title in enumerate(titles[:10], 1) :
    print(f"{i}, {title.text.strip()}")
# Out:
# 1,
# 2, 뉴시스
# 3, 네이버뉴스
# 4, 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공동 공략
# 5, 주요 협력 분야는 ▲글로벌 금융 서비스 모델 공동 발굴 ▲국내 체류 외국인 대상 키오스크 기반 금융 서비스 사업 ▲양자내성암호(PQC) 및 인공지능(AI) 안면인식 설루션을 접목한 글로벌 보안 사업 ▲공동 마케팅 및 파트너사 연계 등이다. 송상엽 한컴위드 대표는 "금 기반 디지털 금융 서비스를 이전부터...
# 6,
# 7, 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공략
# 8, 네이버뉴스
# 9, 한컴위드, 다날과 차세대 디지털 금융 서비스 시장 공동 공략
# 10, 네이버뉴스

# %%
# 다음 뉴스에서 IT 섹션의 기사 제목과 링크 수집

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
driver.get("https://news.daum.net/")

element = driver.find_element(By.XPATH, "//span[contains(text(), 'IT/과학')]")
element.click()
time.sleep(2)

url_list = []
title_list = []
elements = driver.find_elements(By.CSS_SELECTOR, "ul.list_newsheadline2")
for element2 in elements :
    url_list.append(element2.get_attribute("href"))
    title = element2.text.strip()
    title_list.append(title)
print(title_list, url_list)

driver.quit()
# Out:
# ['[AI는 지금] \'속도전\' 넘어 \'신뢰\' 경쟁…AI, 보이지 않는 안전벨트 맨다\n(지디넷코리아=조이환 기자)전 세계가 인공지능(AI) \'속도전\'에 몰두하는 사이 한국이 \'안전\'이라는 카드를 꺼내 들었다. AI 안전연구소가 신뢰성의 컨트롤타워로서 정책을 이끌고 네이버·LG 등 민간 기업들은 개발 현장에서 자체 안전망을 촘촘히 구축하는 \'투트랙\' 전략이다. 30일 업계에 따르면 AI 기술 경쟁이 격화하며 안전 논의가 뒷전으로 밀리고 있다\n지디넷코리아 6분 전\n아태지역 기업, AI 도입 성숙도 \'과대 평가\'…"전략·인재 미흡"\n지디넷코리아 7분 전\nLG, \'세계 11위\' 성적표로 국가 AI 출사표…\'엑사원\'으로 기술력 과시\n지디넷코리아 15분 전\n한미반도체, 美 기업에 HBM 장비 공급 폭증… “HBM4 시장도 독점”\n조선비즈 19분 전\n[주간스타트업동향] 펴다, 투자 경진대회 \'공명전\' 최종 우승 外\nIT동아 21분 전\n딥페이크, AI가 잡았다…AI 과학수사 나선 정부, 성과 \'굿\'\n지디넷코리아 22분 전\n접어도 얇다, 무게도 부담 없다···갤폴드7, 이동 중 업무가 더 쉬워졌네[써보니]\n경향신문 26분 전\n알츠하이머 조기 진단 ‘간단하게’…극미량 체액검사로 진단\n디지털타임스 26분 전\n커지는 미디어부처 개편 목소리…"파편화 시대 끝내야"\n뉴시스 30분 전'] [None]

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/tech"

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

response = requests.get(url, headers = headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

articles = soup.select("ul.list_newsheadline2 li a.item_newsheadline2")

for i, article in enumerate(articles, 1) :
    title = article.text.strip()
    link = article("href")
    print( i, title, link)
# Out:
# 1 中 불법여권으로 대포폰 개통…사각지대 놓인 '일탈' 판매점 (서울=뉴스1) 김정현 기자 = 서울 한 복판에서 불법여권으로 휴대전화를 개통한다고 홍보하는 곳이 한 웹 예능을 통해 포착됐다. 해당 가게는 SKT·KT·LGU+의 로고가 붙어있는 휴대전화 판매점이었다. 이동통신사들과 직접 계약관계를 맺지 않은 판매점들이 불·편법 개통 사각지대에 놓이며 생긴 일이다. 30일 업계에 따르면 최근 유튜브 채널 워크맨의 웹 뉴스1 6분 전 []
# 2 펄어비스 "자체 게임엔진에 기술 역량·창의성 극대화 철학 담아" 아시아경제 6분 전 []
# 3 최주홍 지피유엔 대표 "'테라리움' 본격 방향성 잡아…12월 퍼블리셔 컨택 빌드 목표" 지디넷코리아 9분 전 []
# 4 PBS 제도 폐지 발표…노조는 환영, 과기정통부는 ‘신중 접근’ 조선비즈 14분 전 []
# 5 "피지컬 AI도 '소버린'…한국형 제조 특화 AI로 새 기회 만들자" 머니투데이 14분 전 []
# 6 韓-北美 청정기술 동맹…캐나다 천연자연부와 글로벌 R&D 본격화 헤럴드경제 19분 전 []
# 7 "지멘스 같은 제조 AI 설루션, 한국엔 없다"(종합) 연합뉴스 20분 전 []
# 8 "이젠 대한민국 전역이 多雨 지역… 돌발 홍수, AI로 막는다 이데일리 21분 전 []
# 9 한미반도체 "HBM4 장비 전량 수주할 것…국내 경쟁상대 없어" 연합뉴스 22분 전 []

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
driver.get("https://www.yes24.com/product/category/bestseller?pageNumber=1&pageSize=24&categoryNumber=001001025007")



title_list1 = []
title_list2 = []
elements = driver.find_elements(By.XPATH, "//a[@class='gd_name']")
elements1 = driver.find_elements(By.XPATH, "//span[@class='authPub info_auth']")

for element2 in elements[:10] :
    title1 = element2.text.strip()
    title_list1.append(title1)
for element3 in elements1[:10] :
    title2 = element3.text.strip()
    title_list2.append(title2)
print(f"제목 : {title_list1}, 저자 : {title_list2}")

driver.quit()
# Out:
# 제목 : ['듀얼 브레인', '이웃집 백만장자 (리미티드 에디션)', '세계 경제 지각 변동', '이게 되네? 제미나이 노트북LM 미친 활용법 51제', '더 그레이트 비트코인', '박태웅의 AI 강의 2025', 'AI 에이전트 트렌드&활용백과', '트럼프 시대의 지정학과 비트코인', '달러는 왜 비트코인을 싫어하는가', '왜 그들만 부자가 되는가'], 저자 : ['이선 몰릭 저/신동숙 역', '토머스 J. 스탠리, 윌리엄 D. 댄코 저/홍정희 역', '박종훈 저', '오힘찬 저', '오태민 저', '박태웅 저', '김덕진, 김아람 저', '오태민 저', '사이페딘 아모스 저/위대선 역', '필립 바구스, 안드레아스 마르크바르트 저/배진아 역']

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.daum.net/tech"

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

books = soup.select("ul.yesBestList > li")

for i, book in enumerate(books[:10], 1) :
    title_tag = book.select_one("div.info_row info_name")
    author_tag = book.select_one("span.authPub info_auth")

    if title_tag and author_tag :
        title = title_tag.text.strip()
        author = author_tag.text.strip()
        print(f"{i}, {title}, {author}")

# %%
### 4. 기상청 날씨 페이지, 오늘의 전국 날씨 요약

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
driver.get("https://www.weather.go.kr/w/index.do#dong/1168064000/37.4969749/127.0380107/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%EC%97%AD%EC%82%BC1%EB%8F%99/LOC/%EC%9C%84%EA%B2%BD%EB%8F%84")



weather_list = []
elements = driver.find_elements(By.XPATH, "//div[@class='nation_map_wrapper']")


for element in elements :
    weather = element.find_elements(By.XPATH, "//dl[@*]")
    region = weather.find_elements(By.XPATH, "//dt[@*]")
    state = weather.get_attribute("title")
    tm = weather.find_elements(By.XPATH, "//span")


driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 22
#      20 for element in elements :
#      21     weather = element.find_elements(By.XPATH, "//dl[@*]")
# ---> 22     region = weather.find_elements(By.XPATH, "//dt[@*]")
#      23     state = weather.get_attribute("title")
#      24     tm = weather.find_elements(By.XPATH, "//span")
#
# AttributeError: 'list' object has no attribute 'find_elements'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.weather.go.kr/w/weather/forecast/short-term.do#dong/1168064000/37.4969749/127.0380107/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EA%B0%95%EB%82%A8%EA%B5%AC%20%EC%97%AD%EC%82%BC1%EB%8F%99/LOC/%EC%9C%84%EA%B2%BD%EB%8F%84"

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.text, "html.parser")

summary_tag = soup.select_one("ul.yesBestList > li")

if summary_tag :
    print("오늘의 전국 날씨 요약")
    print(summary_tag.text.strip())
else :
    print("날씨 정보를 찾을 수 없습니다")

# %%
### 5. 잡코리아에서 '데이터 공고 제목 20개 수집'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
driver.get("https://www.jobkorea.co.kr/")

element = driver.find_element(By.XPATH, "//div[@class='smKey']")
element.click()
element1.send_keys("데이터 분석")
element1.send_keys(Keys.RETURN)
time.sleep(2)

title_list = []
elements = driver.find_elements(By.XPATH, "//div[@class='styles_mb_space8__dk46ts1p']")
for element2 in elements[:20] :
    title = element2.text.strip()
    title_list.append(title)
print(title_list)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
keyword = "데이터 분석가"
driver.get(f"https://www.jobkorea.co.kr/Search/?stext={keyword}")


title_list = []
elements = driver.find_elements(By.XPATH, "//div[@class='styles_mb_space8__dk46ts1p']")
for element2 in elements[:20] :
    title = element2.text
    title_list.append(title)
print(f"{title_list}")

driver.quit()
# Out:
# ['데이터 분석가 (경력)', '데이터 분석가', '[CVS] 데이터 분석가(Business Analyst)', '[쿡앱스] 게임 데이터 분석가 모집', '[기어세컨드] 데이터 분석가 채용', '데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통', 'Data Analyst (데이터 분석가)', '[인텔리전스랩스그룹] 데이터 분석가 (인게임 로그 및 비즈니스 인사이트 분석)', '[CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)', '데이터 분석가(신입/경력)', '공공데이터 품질 관리와 진단, 데이터 분석가', '[다우키움 계열사] 데이터 분석가 (경력)', '[통계팀] 데이터 분석가 모집', '[커머스플랫폼팀] 데이터 분석 전문가 (Senior Data Analyst) 모집', '[디저트39] 데이터 분석가(Data Analyst)/데이터 분석 엔지니어 팀장급', '데이터분석가 구인', '[어니컴(주)] 데이터분석가 신입/경력 모집', '[(중급이상/ 경력직)] 빅데이터 전문가를 모십니다', '데이터분석가 채용(경력)', '[리비바이오] 데이터분석가']

# %%
import requests
from bs4 import BeautifulSoup



headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

quary = "데이터 분석가"

url = f"https://www.jobkorea.co.kr/Search/?stext={quary}"

response = requests.get(url, headers = headers)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")

titles = soup.select("div.styles_mb_space8__dk46ts1p a.sn28bt0")

for i, title_tag in enumerate(titles[:20], 1) :
    print(f"{i}, {title_tag.text.strip()}")
# Out:
# 1, 데이터 분석가 (경력)
# 2, 데이터 분석가
# 3, [CVS] 데이터 분석가(Business Analyst)
# 4, [쿡앱스] 게임 데이터 분석가 모집
# 5, [기어세컨드] 데이터 분석가 채용
# 6, 데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 7, Data Analyst (데이터 분석가)
# 8, [인텔리전스랩스그룹] 데이터 분석가 (인게임 로그 및 비즈니스 인사이트 분석)
# 9, [CVS] 데이터 분석가 1년 인턴 (Business Analyst Intern)
# 10, 데이터 분석가(신입/경력)
# 11, 공공데이터 품질 관리와 진단, 데이터 분석가
# 12, [다우키움 계열사] 데이터 분석가 (경력)
# 13, [통계팀] 데이터 분석가 모집
# 14, [커머스플랫폼팀] 데이터 분석 전문가 (Senior Data Analyst) 모집
# 15, [디저트39] 데이터 분석가(Data Analyst)/데이터 분석 엔지니어 팀장급
# 16, 데이터분석가 구인
# 17, [어니컴(주)] 데이터분석가 신입/경력 모집
# 18, [(중급이상/ 경력직)] 빅데이터 전문가를 모십니다
# 19, 데이터분석가 채용(경력)
# 20, [리비바이오] 데이터분석가

# %%
from selenium import webdriver
import openpyxl
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time

wb = openpyxl.Workbook()
ws = wb.active
ws.title = "JobKorea 공고"
ws.append(["공고명", "URL"])
service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
keyword = "데이터 분석가"
i = 0

while i < 6 :
    i += 1
    driver.get(f"https://www.jobkorea.co.kr/Search/?stext={keyword}&local=I000&tabType=recruit&Page_No={i}&careerType=2&careerMin=1&careerMax=3")
    title_list = []
    elements = driver.find_elements(By.CSS_SELECTOR, "div.styles_mb_space8__dk46ts1p a")
    for element2 in elements[:20] :
        title = element2.text.strip()
        url_list = element2.get_attribute("href")
        ws.append([title, link])
    time.sleep(2)
wb.save("job코리아 공고.xlsx")

print("엑셀저장 완료")

driver.quit()
# Out:
# 엑셀저장 완료

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import urllib.parse
import pandas as pd

option = Options()
option.add_argument("headless")
option.add_argument("window-size=1920x1080")
option.add_argument("--start-maximized")
option.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
option.add_argument("lang=ko_KR")
service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=option)
query = "데이터 분석가"
encoded_query = urllib.parse.quote(query)

max_pages = 6

results =[]
for page in range(1, max_pages + 1) :
    url = f"https://www.jobkorea.co.kr/Search/?stext={encoded_query}&local=I000&tabType=recruit&Page_No={page}&careerType=2&careerMin=1&careerMax=3"
    driver.get(url)
    time.sleep(2)

    job_posts = driver.find_elements(By.CSS_SELECTOR, "div.styles_mb_space8__dk46ts1p")
    for post in job_posts :
        try:
            title_elem = post.find_element(By.CSS_SELECTOR, "a.sn28bt0")
            title = title_elem.text.strip()
            link = title_elem.get_attribute("href")
            results.append({
                "제목" : title,
                "지원링크" : link
            })
        except :
            continue
            
driver.quit()


df = pd.DataFrame(results)
df.to_excel("잡코리아_데이터분석가_서울_신입.xlsx", index=False)
print("엑셀저장 완료")
# Out:
# 엑셀저장 완료
