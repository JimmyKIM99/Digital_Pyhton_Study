# %%
import requests
from bs4 import BeautifulSoup
from openpyxl import Workbook

url = "https://www.kurly.com/goods/1001303410"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

text = soup.select(".css-y49dcn e36z05c13")
print(text)
# Out:
# []

# %%
pip install selenium
# Out:
# ...
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# selenium.webdriver.chrome.options.Options
# selenium.webdriver.Chrome()

from bs4 import BeautifulSoup
import time

# 1. 셀레니움 기본 옵션 설정
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--headless")

driver = webdriver.Chrome(options = options)

# 2. 페이지 접속
url = "https://www.kurly.com/goods/1001303410"
driver.get(url)

time.sleep(5) # 페이지 로딩대기 시간

# 3. HTML 가져오기
soup = BeautifulSoup(driver.page_source, "html.parser")
reviews = soup.select("p.css-y49dcn.e36z05c13")
for review in reviews :
    print(review.get_text().strip())

driver.quit() # 4. 꼭 나가줘야 함
# Out:
# 완도 전복 정말 신선하게 잘 도착했어요.
# 산소포장 덕분에 배송 중에도 생생하게 유지되어서 바로 요리에 사용할 수 있었고, 껍질도 깨끗해서 손질도 수월했어요.
# 크기도 생각보다 실해서 놀랐고, 전복살이 통통하게 올라와 있어서 식감도 훌륭했어요.
# 저는 방울양배추랑 새우랑 함께 버터에 구워서 식구들과 함께 먹었는데, 고소한 향과 함께 쫄깃한 전복 식감이 어우러져 정말 맛있었어요.
# 가족들도 너무 맛있다고 극찬해서 기분 좋았고요.
# 집에서도 간편하게 고급 해산물 요리를 즐길 수 있다는 게 정말 큰 장점이었어요.
# 전복죽이나 찜, 구이 등 다양하게 활용할 수 있을 것 같아 자주 구매할 듯합니다.
# 신선함, 품질, 만족도 모두 최고예요.
# 신선하구 튼실한 전복이 왔어요..
# 얼마전 제주도에 갔을때 전복솥밥을
# 맛있게 먹었었기에 따라쟁이를 해봤는데
# 아주 성공적 이었기에 레시피 남겨봅니다.
#
# ☆ 전복솥밥 ☆
#
# # 흑돼지 대신 소고기를 쓰구, 버터가
# 안들어간것 말고는 얼추 비슷하게
# 흉내낸것 같아요.
#
# ​* 한시간 전쯤 쌀을 물에 담가놔요.
#
# * 전복 내장과 쌀을 참기름에 볶아요.
#
# * 물을 붓고 밥을 지어요.
#
# * 소고기 다짐육에 참기름, 소금,
# 다진마늘 넣구 볶아요.
#
# * 다진마늘, 다진쪽파, 참기름, 깨, 간장,
# 청양초 다져넣고 양념장을 만들어요.
#
# * 밥 뜸드는 과정에서 다짐육 펴놓고
# 편 썰기한 전복을 둘러놓구 뚜껑덮구
# 조금더 열을가해요.
#
#
# * 전복이 익으면 불 끄고 김가루 추가하구
# 양념장으로 비벼서 맛있게 먹어요.
# ------------------------
# # 두릅 선물을 받아서 뜸들이는 과정에서
# 고기대신 두릅을숭덩숭덩 썰어넣고도 만들어 봤어요.
# 이번에는 버터도 넣었더니 아주 향긋허니 맛있더라구요 ^^
# 💟 내돈내산 강추후기 💟
# 컬리템들로 완성한 ✨전복 청경채 알리오올리오 파스타✨ !
#
# 1.맛
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# selenium.webdriver.chrome.options.Options
# selenium.webdriver.Chrome()

from bs4 import BeautifulSoup
import time
from openpyxl import Workbook


# 1. 셀레니움 기본 옵션 설정
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--headless")

driver = webdriver.Chrome(options = options)

# 2. 페이지 접속
url = "https://www.kurly.com/goods/1001303410"
driver.get(url)

time.sleep(5) # 페이지 로딩대기 시간

# 3. HTML 가져오기
soup = BeautifulSoup(driver.page_source, "html.parser")
reviews = soup.select("p.css-y49dcn.e36z05c13")
review_lists = [review.get_text().strip() for review in reviews]



driver.quit() # 4. 꼭 나가줘야 함


wb = Workbook()
ws = wb.active
ws.title = "Kurly Reviews"

ws.append(["리뷰내용"])
for item in review_lists :
    ws.append([item])
wb.save("kurly_rewvies.xlsx")
print("엑셀저장완료 : kurly_reviews.xlsx")
# Out:
# 엑셀저장완료 : kurly_reviews.xlsx
