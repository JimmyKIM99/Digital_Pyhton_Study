# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)
driver.get("https://www.melon.com/chart/")
time.sleep(3)

titles = driver.find_elements(By.CSS_SELECTOR, "div.ellipsis.rank01")
artists = driver.find_elements(By.CSS_SELECTOR, "div.ellipsis.rank02")

for artist in artists :
    item1 = artist.text.strip()
for title in titles :
    item2 = title.text.strip()
    print(f"제목 : {item2}, 아티스트 : {item1}")


driver.quit()
# Out:
# 제목 : Golden, 아티스트 : 임영웅
# 제목 : Soda Pop, 아티스트 : 임영웅
# 제목 : FAMOUS, 아티스트 : 임영웅
# 제목 : 뛰어(JUMP), 아티스트 : 임영웅
# 제목 : Drowning, 아티스트 : 임영웅
# 제목 : Dirty Work, 아티스트 : 임영웅
# 제목 : 시작의 아이, 아티스트 : 임영웅
# 제목 : 너에게 닿기를, 아티스트 : 임영웅
# 제목 : Your Idol, 아티스트 : 임영웅
# 제목 : WICKED, 아티스트 : 임영웅
# 제목 : 어제보다 슬픈 오늘, 아티스트 : 임영웅
# 제목 : 모르시나요(PROD.로코베리), 아티스트 : 임영웅
# 제목 : Whiplash, 아티스트 : 임영웅
# 제목 : like JENNIE, 아티스트 : 임영웅
# 제목 : HOME SWEET HOME (feat. 태양, 대성), 아티스트 : 임영웅
# 제목 : How It’s Done, 아티스트 : 임영웅
# 제목 : Never Ending Story, 아티스트 : 임영웅
# 제목 : 시작의 아이 ❍, 아티스트 : 임영웅
# 제목 : 청춘만화, 아티스트 : 임영웅
# 제목 : 나는 반딧불, 아티스트 : 임영웅
# 제목 : APT., 아티스트 : 임영웅
# 제목 : TOO BAD (feat. Anderson .Paak), 아티스트 : 임영웅
# 제목 : HAPPY, 아티스트 : 임영웅
# 제목 : 오늘만 I LOVE YOU, 아티스트 : 임영웅
# 제목 : 빌려온 고양이 (Do the Dance), 아티스트 : 임영웅
# 제목 : REBEL HEART, 아티스트 : 임영웅
# 제목 : STYLE, 아티스트 : 임영웅
# 제목 : 눈물참기, 아티스트 : 임영웅
# 제목 : HANDS UP, 아티스트 : 임영웅
# 제목 : 운명 (2025), 아티스트 : 임영웅
# 제목 : 천상연, 아티스트 : 임영웅
# 제목 : 한 페이지가 될 수 있게, 아티스트 : 임영웅
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://scholar.google.com/scholar?hl=ko&as_sdt=0%2C5&q=SEO+Marketing&btnG=")
time.sleep(3)
b_titles = []
titles = driver.find_elements(By.XPATH, "//h3[@class='gs_rt']")[:5]
time.sleep(3)

for title in titles :
    b_titles.append(title.text.strip().replace(' ','').replace('\n',''))
print(f"제목 : {b_titles}")
driver.quit()
# Out:
# 제목 : ['[책]InboundmarketingandSEO:InsightsfromtheMozBlog', 'Theroleofsearchengineoptimizationinsearchmarketing', 'Applicationmarketingstrategysearchengineoptimization(SEO)', '[책]Optimize:HowtoattractandengagemorecustomersbyintegratingSEO,socialmedia,andcontentmarketing', '[PDF]¿Marketingonline?¿SEO?¿SEM?Conceptosbásicos']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
import re

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.tiobe.com/tiobe-index/")
time.sleep(3)
b_titles = []
titles = driver.find_elements(By.XPATH, "//table[contains(@class, 'table-top20')]")
time.sleep(3)
    
for title in titles :
    language = title.find_elements(By.TAG_NAME, "td")
    for language10 in language :
        l = language10.text.strip().replace(' ','')
        rtitle = re.sub(r'[0-9%-.]+','',l)
        if rtitle != '' :
            b_titles.append(rtitle)
print(f"언어 : {b_titles[:10]}")
driver.quit()
# Out:
# 언어 : ['Python', 'C', 'C', 'Java', 'C#', 'JavaScript', 'VisualBasic', 'Go', 'Perl', 'Delphi/ObjectPascal']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
import re

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)
b_titles = []

driver.get("https://www.data.go.kr/tcs/dss/selectDataSetList.do?keyword=%EC%86%8C%EB%B9%84&brm=&svcType=&recmSe=N&conditionType=init&extsn=&kwrdArray=")
time.sleep(3)

titles = driver.find_elements(By.CSS_SELECTOR, "a span.title")
time.sleep(3)
    
for title in titles :
    b_titles.append(title.text.strip())
print(f"제목 : {b_titles[:10]}")
driver.quit()
# Out:
# 제목 : ['소득소비조사', '인천광역시_소비 데이터', '국토연구원_부동산시장 소비심리 정보', '대전광역시 유성구_법정동별 소비금액 데이터', '대전광역시 유성구_건당 평균 소비 데이터', '농림축산식품부_우유 및 유제품 생산소비현황', '제주특별자치도_단체/개별 관광객 소비 데이터', '한국남부발전(주)_연료소비실적 정보', '한국서부발전(주)_연료소비실적 조회서비스', '한국중부발전(주)_연료소비실적 조회서비스']
