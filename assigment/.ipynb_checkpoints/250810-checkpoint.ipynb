# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://terms.naver.com/entry.naver?docId=2275742&cid=42266&categoryId=51204")


titles = driver.find_elements(By.XPATH, "//p[@class='txt']")

for title in titles :
    print(title.text.strip().replace('/n','').replace('\n',''))


driver.quit()
# Out:
# 콘텐츠산업은 21세기 창조경제를 견인할 핵심 성장 동력으로 각광받고 있고, 디지털 미디어의 다원화로 산업이 성장하고 있지만, 동시에 콘텐츠 사업자간 경쟁은 더욱 치열해지고 있다. 콘텐츠 기업은 사업 분야와 역량에 따라 제작, 유통, 단말 등 강점을 갖는 사업 영역이 있다. 성장과 경쟁의 압박 속에서 이익의 창출이 어려워질수록 각 산업의 핵심가치에 기반한 전략이 빛을 발하게 되는데, 콘텐츠산업의 중심에는 소비자, 즉 고객이 존재한다. 고객과 직접 대면하며, 고객과의 관계 속에서 미래성장의 가능성을 발견하는 콘텐츠사업자들의 핵심적인 10대 전략을 분석하고, 콘텐츠산업의 미래성장 가능성을 진단한다.콘텐츠산업은 21세기 창조경제를 견인할 핵심 성장 동력으로 각광받고 있고, 디지털 미디어의 다원화로 산업이 성장하고 있지만, 동시에 콘텐츠 사업자간 경쟁은 더욱 치열해지고 있다. 콘텐츠 기업은 사업 분야와 역량에 따라 제작, 유통, 단말 등 강점을 갖는 사업 영역이 있다. 성장과 경쟁의 압박 속에서 이익의 창출이 어려워질수록 각 산업의 핵심가치에 기반한 전략이 빛을 발하게 되는데, 콘텐츠산업의 중심에는 소비자, 즉 고객이 존재한다. 고객과 직접 대면하며, 고객과의 관계 속에서 미래성장의 가능성을 발견하는 콘텐츠사업자들의 핵심적인 10대 전략을 분석하고, 콘텐츠산업의 미래성장 가능성을 진단한다.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://korean.visitkorea.or.kr/list/travelcourse.do?service=cs")
p_cities = []
titles = []

cities = driver.find_elements(By.CSS_SELECTOR, "#arealist")
for city in cities :
    city_name = city.text.strip().split("\n")
    p_cities.extend(city_name)
    
for p_city in p_cities :
    click_city = driver.find_element(By.XPATH, f"//span[contains(text(),'{p_city}')]")
    click_city.click()
    time.sleep(2)
    travel_titles = driver.find_elements(By.CSS_SELECTOR, "div.tit")
    for title in travel_titles :
        c_title = title.text.strip().replace(' ','').replace('\n','')
        if c_title != '' :
            titles.append(c_title)
    print(f"{p_city} : {titles}")
driver.quit()
# Out:
# #전체 : ['안전에서역사까지익산의오감여행코스', '안전과힐링이함께하는제천여행코스', '안전과여유,감동을함께누리는담양여행코스', '안전,예술,바다,명소까지올인원여수관광코스', '제주올레길', '가족끼리대부도나들이', '누구나가기좋은익산나들이코스', '낮에보아도밤에보아도아름다운남원1박2일코스', '서해랑길(고창,군산구간)', '달(月)달(月)한남원여행']
# #서울 : ['안전에서역사까지익산의오감여행코스', '안전과힐링이함께하는제천여행코스', '안전과여유,감동을함께누리는담양여행코스', '안전,예술,바다,명소까지올인원여수관광코스', '제주올레길', '가족끼리대부도나들이', '누구나가기좋은익산나들이코스', '낮에보아도밤에보아도아름다운남원1박2일코스', '서해랑길(고창,군산구간)', '달(月)달(月)한남원여행', '서울의대문숭례문과그주변의사람들을찾아', '청와대앞코스돌아보기', '서울의아름다운밤을바라보다.', '서울의역사중심지를걷다', '한양의500년도읍을거닐다', '서울양천구서서울호수공원코스', '서울의하이드파크와전통시장', '한양도성안궁궐과학교이야기', '궁의북쪽자하문돌아보기', '과거와현재의시간이겹쳐진부암동길']
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://brunch.co.kr/")
b_titles = []
t_titles = []
time.sleep(5)
titles = driver.find_elements(By.CSS_SELECTOR, "div.embla__slide")

for title in titles :
    b_titles = title.text.strip().replace(' ','').replace('\n','')
    time.sleep(3)
    if b_titles != '' :
        t_titles.append(b_titles)
    try :
        for next_1 in range(6) :
            next_1 = driver.find_element(By.XPATH, "//span[contains(text(),'다음 에디터픽 보기')]")
            next_1.click()
            time.sleep(2)
    except :
        continue
print(t_titles)
driver.quit()
# Out:
# ['08:09:46brunchmembership신입공채자소서어떻게써야할까by산들', '치앙마이의먹기사정치앙마이에서아무리봐도질리지않는광경중하나는사람들이음식을...by와리', '내가밖에서도너한테친절하겠니다정한사람은좋은사람일까?그렇다면나는좋은사람이아니었는지...by낭생이직장인출신로스쿨생의로스쿨적응기-상편by사무관과변호사강아지산책시키다늙는이야기by이정현저는육아광인입니다by동그란도나츠']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)


driver.get("https://store.kyobobook.co.kr/bestseller/online/weekly/domestic/13")
time.sleep(5)
b_titles = []
titles = driver.find_elements(By.CSS_SELECTOR, "a.prod_link.line-clamp-2")
time.sleep(5)

for title in titles :
    b_titles.append(title.text.strip().replace(' ','').replace('\n',''))
print(f"제목 : {b_titles}")
driver.quit()
# Out:
# 제목 : ['박곰희연금부자수업', '예약판매기술공화국선언', '워런버핏삶의원칙', '새로운질서', '비트코인슈퍼사이클2026', '글로벌주식투자빅시프트', '예약판매실패를성공으로바꾸는주식투자의기술(불장에디션)', '미치도록보고싶었던돈의얼굴', '통찰경영', '초보자를단숨에고수로만드는주식투자핵심수업', '돈의심리학(30만부기념스페셜에디션)', '이웃집백만장자(리미티드에디션)', '심리투자불변의법칙', '인생을바꾸는최고의ETF', '단3개의미국ETF로은퇴하라', '제로투원(10주년기념판)', '자본주의', '돈의속성(400쇄리커버에디션)', '워런버핏웨이', '세계경제지각변동']
