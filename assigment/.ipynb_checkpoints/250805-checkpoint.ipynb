# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

keyword = "마케팅"
driver.get(f"https://ko.wikipedia.org/wiki/{keyword}")

paragraph = driver.find_element(By.XPATH, "(//p)[1]")
print(paragraph.text)

driver.quit()
# Out:
# 마케팅(영어: marketing)은 시장 경제(영어: exchange relationship) 또는 수요를 관리하는 경영학의 한 분야이다. 소비자를 대상으로 고객을 창조하고 유지 · 관리함으로써 고정고객으로 만드는 모든 활동 즉, 고객과 관련된 모든 활동을 의미한다. 마케팅은 광고, 영업 등을 포함하며 창의성을 내포하는 산업이자 소비자가 가질 수 있는 미래의 요구와 욕구를 예측하는 일로 한정되었으나 21세기 이후에는 어떤 '잠재적인 욕구'를 자극하여 표면상으로 이끌어 내는 행위나 동기로 용어의 적용 범위가 확대되고, 시장에서 벗어나 일상의 행위에서도 마케팅이라는 용어가 등장하게 되었다.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

keyword = "마케팅"
driver.get("https://data.seoul.go.kr/dataList/datasetList.do?datasetKind=1&searchFlag=M")

titles = driver.find_elements(By.XPATH, "//a[@href='#']")[:10]
for title in titles :
    print(title.text)

driver.quit()
# Out:
# 사이트맵
# 상상대로 서울 자유제안 정보
# 서울글로벌센터 접수유형 및 상담유형별(월) 상담실적
# 서울글로벌센터 상담유형별(월) 상담실적
# 서울글로벌센터 상담유형별(분기) 상담실적
# 서울글로벌센터 접수유형별 언어별 상담실적
# 서울시 위생업소 전체 행정처분내역 현황
# 서울시 기타 위생용품 제조업 현황
# 서울시 중구 위생처리업 공중위생업소 현황
# 서울시 세척제 제조업 현황

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://tickets.interpark.com/contents/ranking?genre=MUSICAL")

Musicals = driver.find_elements(By.CSS_SELECTOR, "div.responsive-ranking-list_rankingItem__PuQPJ")

for musical in Musicals :
    title = musical.find_element(By.CSS_SELECTOR, "li.responsive-ranking-list_goodsName__aHHGY")
    place = musical.find_element(By.CSS_SELECTOR, "li.responsive-ranking-list_placeName__9HN2O")
    date = musical.find_element(By.CSS_SELECTOR, "div.responsive-ranking-list_dateWrap__jBu5n")
    print(f"제목 : {title.text.strip()}, 장소 : {place.text.strip()}, 날짜 : {date.text.strip().replace('\n',"")}")


driver.quit()
# Out:
# 제목 : 뮤지컬 〈스웨그에이지 외쳐,조선!〉, 장소 : 홍익대 대학로 아트센터 대극장, 날짜 : 2025.6.20~8.31
# 제목 : 뮤지컬 〈마하고니〉, 장소 : 링크아트센터 페이코홀, 날짜 : 2025.6.17~8.31
# 제목 : 뮤지컬 〈위키드〉 내한 공연(WICKED The Musical), 장소 : 블루스퀘어 신한카드홀, 날짜 : 2025.7.12~10.26
# 제목 : 뮤지컬 〈스트라빈스키〉, 장소 : 대학로 TOM(티오엠) 2관, 날짜 : 2025.7.28~10.12
# 제목 : 뮤지컬 〈브로드웨이 42번가〉, 장소 : 샤롯데씨어터, 날짜 : 2025.7.10~9.14
# 제목 : 뮤지컬 〈노트르담 드 파리〉 프렌치 오리지널 내한공연 한국투어 20주년, 장소 : 세종문화회관 대극장, 날짜 : 2025.9.3~9.27
# 제목 : 뮤지컬 〈멤피스〉, 장소 : 충무아트센터 대극장, 날짜 : 2025.6.17~9.21
# 제목 : 〈슬립노모어 서울〉 (Sleep No More Seoul), 장소 : 매키탄 호텔 (The McKithan Hotel), 날짜 : 2025.7.24~9.28
# 제목 : 맘마미아!, 장소 : LG아트센터 서울 LG SIGNATURE 홀, 날짜 : 2025.7.26~10.25
# 제목 : 뮤지컬 〈마리 퀴리〉, 장소 : 광림아트센터 BBCH홀, 날짜 : 2025.7.25~10.19
# 제목 : 뮤지컬 〈팬텀〉 10주년 기념 공연, 장소 : 세종문화회관 대극장, 날짜 : 2025.5.31~8.11
# 제목 : 태양의서커스 〈쿠자〉, 장소 : 잠실종합운동장 내 빅탑, 날짜 : 2025.10.11~12.28
# 제목 : 뮤지컬 〈알라딘〉 한국 초연 - 부산 (ALADDIN The Musical), 장소 : 부산 드림씨어터, 날짜 : 2025.7.11~9.28
# 제목 : 뮤지컬 위대한개츠비(The Great Gatsby) - 서울 오리지널 프로덕션, 장소 : GS아트센터, 날짜 : 2025.8.1~11.9
# ...
