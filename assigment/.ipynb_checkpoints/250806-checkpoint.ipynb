# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://portal.scourt.go.kr/pgp/index.on?m=PGP1011M01&l=N&c=900")
time.sleep(3)

titles = driver.find_elements(By.XPATH, "//a[@title='새 창 열림']")[:10]
time.sleep(3)

for title in titles :
    print(title.text.strip())


driver.quit()
# Out:
# 대법원 2023.12.07 선고 2020도15393 판결 [근로기준법위반ㆍ근로자퇴직급여보장법위반]〈1주간 12시간의 연장근로한도 위반 여부가 문제된 사건〉 [공2024상,161]
# 대법원 2023.12.07 선고 2023다246600 판결 [손해배상(기)]〈집합건물 시공자가 구분소유자에 대하여 부담하는 담보책임이 문제된 사건〉 [공2024상,114]
# 대법원 2023.12.07 선고 2023다269139 판결 [소유권이전등기]〈아파트 매매계약서에 인도일과 실제 명도일 약정이 별도로 있는 경우 매도인의 현실인도의무 인정 여부가 문제된 사건〉 [공2024상,117]
# 대법원 2023.12.07 선고 2022다279795 판결 [건물인도]〈임차인의 계약갱신 요구에 대하여 임대인이 실제 거주를 이유로 갱신거절한 후 그 주택의 인도를 구하는 사건〉 [공2024상,110]
# 대법원 2023.12.07 선고 2020도17863 판결 [저작권법위반ㆍ부정경쟁방지및영업비밀보호에관한법률위반]〈외국에서 수입·판매한 만화 캐릭터 미니블록 제품에 대한 배포권 침해 여부가 문제된 사건〉 [공2024상,165]
# 대법원 2023.12.07 선고 2020두42668 판결 [법인지방소득세경정거부처분취소]〈개정된 세법 부칙조항을 근거로 납세의무자에게 유리한 종전 규정을 적용하기 위한 요건〉 [공2024상,147]
# 대법원 2023.11.30 선고 2023다259743 판결 [임대차보증금]〈다가구주택 임대차계약을 중개한 공인중개사의 주의의무 이행 여부가 문제된 사건〉 [공2024상,104]
# 대법원 2023.11.30 선고 2022다280283 판결 [손해배상(기)]〈일제 강제징용 노동자상을 제작·설치한 조각가 부부가 해당 노동자상의 모델이 일본인이라는 발언 등을 한 피고를 상대로 손해배상을 청구한 사건〉 [공2024상,97]
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://news.samsung.com/kr/latest/")

# newses = driver.find_elements(By.CSS_SELECTOR, "ul.item")
titles = driver.find_elements(By.CSS_SELECTOR, "span.title.ellipsis")
dates = driver.find_elements(By.CSS_SELECTOR, "span.date")

for date in dates :
    item1 = date.text.strip()
for title in titles :
    item2 = title.text.strip()
    print(f"제목 : {item2}, 날짜 : {item1}")


driver.quit()
# Out:
# 제목 : 삼성전자, 게임스컴 2025 참가… 통합 게이밍 경험 제공, 날짜 : 2025/08/04
# 제목 : One UI 8.0를 통해 만나는 새로운 갤럭시 벨소리… 비발디 ‘사계’, 날짜 : 2025/08/04
# 제목 : 삼성전자, 갤럭시 Z 폴드6 등 기존 모델 대상 One UI 8 베타 프로그램 확대 운영, 날짜 : 2025/08/04
# 제목 : 삼성전자, 에너지 효율 강화한 ‘비스포크 식기세척기 카운터탑’ 신제품 출시, 날짜 : 2025/08/04
# 제목 : “여행도 스마트하게” 갤럭시 Z 폴드7의 갤럭시 AI가 바꾸는 여행의 기준, 날짜 : 2025/08/04
# 제목 : 삼성 TV 플러스, 조나스 브라더스 데뷔 20주년 투어 전 세계 독점 생중계, 날짜 : 2025/08/04

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.lottecinema.co.kr/NLCHS/Movie/List?flag=1")

# newses = driver.find_elements(By.CSS_SELECTOR, "ul.item")
titles = driver.find_elements(By.CSS_SELECTOR, ".tit_info")
for title in titles :
    item2 = title.text.strip()
    print(f"제목 : {item2}")


driver.quit()
# Out:
# 제목 : 좀비딸
# 제목 : F1 더 무비
# 제목 : 발레리나
# 제목 : 킹 오브 킹스
# 제목 : 전지적 독자 시점
# 제목 : 스머프
# 제목 : 야당: 익스텐디드 컷
# 제목 : 배드 가이즈 2
# 제목 : [보석특가]죠스
# 제목 : 추적
# 제목 : 고고다이노 극장판: 게코도마뱀의 꿈
# 제목 : 명탐정 코난: 척안의 잔상
# 제목 : 극장판 도라에몽: 진구의 그림이야기
# 제목 : 베베핀 극장판: 사라진 베베핀과 핑크퐁 대모험
# 제목 : 판타스틱 4: 새로운 출발
# 제목 : 영화 코바야시네 메이드래곤 외로움쟁이 용
# 제목 : 노이즈
# 제목 : [보석특가]셔터 아일랜드
# 제목 : 탑건: 매버릭
# 제목 : 시네마 천국
# 제목 : 쥬라기 월드: 새로운 시작
# 제목 : 수연의 선율
# 제목 : 스즈메의 문단속
# 제목 : 라라랜드
# 제목 : 여름이 지나가면
# 제목 : 이사
# 제목 : 여름정원
# 제목 : 침몰 10년, 제로썸
# 제목 : 괴기열차
# 제목 : 무명
# 제목 : 발코니의 여자들
# 제목 : 비밀의 화원
# 제목 : 소주전쟁
# 제목 : 신명
# 제목 : 알사탕
# 제목 : 어네스트와 셀레스틴: 멜로디 소동
# 제목 : 엘리오
# 제목 : 우리 둘 사이에
# 제목 : 우리들의 교복시절
# 제목 : 일과 날
# 제목 : 퇴마록

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.nocutnews.co.kr/news/entertainment")


titles = driver.find_elements(By.CSS_SELECTOR, "p strong.clamp2")[:5]


for title in titles :
    print(title.text.strip())


driver.quit()
# Out:
# '부친상' 이수근 측 "유가족 상의 끝 조문 받기로"
# "나 강아지 생겼다"…영화 '릴로 & 스티치' 디즈니+ 공개 확정
# '검은 수녀들'→'파과'…올해 양성평등 영화 10편은?
# 롯데시네마, 슈퍼주니어 월드투어 '슈퍼쇼 10' 단독 라이브뷰잉
# '존 윅' 잇는 킬링 액션 '발레리나', 오늘(6일) 개봉

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.sooplive.co.kr/")


titles = driver.find_elements(By.CSS_SELECTOR, "div.cBox-list h3.title a")

for title in titles :
    print(title.text)


driver.quit()
# Out:
# 하이YO 츠캄
# 랭커의 품격 랭킹4등에게 배우다 포카칩퍼런거 챌달리기 노방종.
# [ DK vs BRO ] 프로 코치 LCK CL 예측 및 분석 #LCKCLWatchParty
# BFX vs KT ㅣ 2025 LCK CL ROUND 3
# 철구 초비상사태...
# 김건희특검출석⭐YTN연합뉴스생방송JTBC폭우날씨속보MBN시사팩트TV조선국회실시간한국경제일본미국주식비트코인스포퀵뷰룸야구스타애니공식정치타파
# 새벽에 좀비 세상에서 살아남ㄱㅣ... (새로운 모드추가)
# 스타 선발전 호미밍vs 유태 감컴퍼니
# 에헤이.... ..감컴퍼니1
# JSA) 영입 발표가 있습니다.
# 롤체 스킨만 120만원 쓰고 안한사람.
# [보연동/꾸산당2]예선A조 친해지길바라우 TFT 멸망전 예선전
# 청춘실버는 마스터의 꿈을꾼다
# 시즌 15 )⭐ TFT멸망전 예선 1시 ⭐
# 1시 멸망전 예선
# [신입여캠] 나랑 놀자!!!
# 60일 신입여캠 ) By 레니 회장님이 선물해주신 라부부 오픈식
# 신입여캠 ㄱㅣ 다림의 미 학 1484 정성방셀
# 신입여캠 24일차 팬가입시 노래해두림다
# 아침을 함께하쟈

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.myrealtrip.com/")
time.sleep(2)

remove_click = driver.find_element(By.XPATH, "//span[@class='css-a0l7zb']")
remove_click.click()
time.sleep(2)

start_click = driver.find_element(By.CSS_SELECTOR, "div.css-84r5kt svg.mrt-web-icons")
start_click.click()
time.sleep(2)
p_cities = []
titles = []
except_city = '제주'

cities = driver.find_elements(By.CSS_SELECTOR, "div.css-7xtxvt")
for city in cities :
    city_name = city.text.strip().split("\n")
    p_cities.extend(city_name)
    
for p_city in p_cities :
    if p_city in except_city :
        print("제외도시")
        continue
    click_city = driver.find_element(By.XPATH, f"//span[contains(text(),'{p_city}')]")
    click_city.click()
    time.sleep(2)
    travel_titles = driver.find_elements(By.CSS_SELECTOR, "div.css-36dip9 div.css-bakj5m")
    for title in travel_titles :
        t_title = title.text.strip().replace(' ','').replace('\n','')
        if t_title != '' :
            titles.append(t_title)

    start_click = driver.find_element(By.CSS_SELECTOR, "div.css-84r5kt svg.mrt-web-icons")
    start_click.click()
    time.sleep(2)

    print(f"도시 : {p_city} / 상품명 : {titles}")

driver.quit()
# Out:
# 도시 : 나트랑 상품명 : ['퓨전리조트깜란459,244원', '보마리조트나트랑140,016원', '빌라르코라이그란멜리아180,315원', '셀렉텀노아리조트캄란165,289원', '멜리아빈펄깜란비치리조트442,647원', '알마리조트177,059원']
# 도시 : 후쿠오카 상품명 : ['퓨전리조트깜란459,244원', '보마리조트나트랑140,016원', '빌라르코라이그란멜리아180,315원', '셀렉텀노아리조트캄란165,289원', '멜리아빈펄깜란비치리조트442,647원', '알마리조트177,059원', '[산큐패스]규슈무제한버스패스71,500원', '[라쿠투어]다자이후·유후인·벳푸버스투어5%37,905원', '[라쿠투어]히타·유후인·유후다케·벳푸버스투어5%37,905원', '[즉시확정]JR북큐슈레일패스66,400원', '[여행한그릇]다자이후·유후인·벳푸버스투어5%46,550원', '후쿠오카수족관입장권:마린월드22,000원']
# 도시 : 오사카 상품명 : ['퓨전리조트깜란459,244원', '보마리조트나트랑140,016원', '빌라르코라이그란멜리아180,315원', '셀렉텀노아리조트캄란165,289원', '멜리아빈펄깜란비치리조트442,647원', '알마리조트177,059원', '[산큐패스]규슈무제한버스패스71,500원', '[라쿠투어]다자이후·유후인·벳푸버스투어5%37,905원', '[라쿠투어]히타·유후인·유후다케·벳푸버스투어5%37,905원', '[즉시확정]JR북큐슈레일패스66,400원', '[여행한그릇]다자이후·유후인·벳푸버스투어5%46,550원', '후쿠오카수족관입장권:마린월드22,000원', '[입장권]유니버셜스튜디오재팬83,000원', '간사이공항-난바역라피트편도티켓9%10,300원', '오사카주유패스1일권2일권29,800원', '[익스프레스4]유니버셜스튜디오재팬96,700원', '[여행한그릇]교토1일버스투어5%46,550원', '오사카하루카스300전망대입장권30%11,900원']
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://likms.assembly.go.kr/bill/LatestPassedBill.do")


titles = driver.find_elements(By.CSS_SELECTOR, "td.alignL a")

for title in titles :
    law_title = title.get_attribute("title")
    print(law_title)


driver.quit()
# Out:
# 방송법 일부개정법률안(대안)
# 의사일정 변경동의의 건(문진석의원 등 167인)
# 공항시설법 일부개정법률안(대안)
# 보건의료기본법 일부개정법률안(대안)
# 건설산업기본법 일부개정법률안(대안)
# 빈집 및 소규모주택 정비에 관한 특례법 일부개정법률안(대안)
# 도시공원 및 녹지 등에 관한 법률 일부개정법률안(대안)
# 지방교육재정교부금법 일부개정법률안(대안)
# 농수산물 유통 및 가격안정에 관한 법률 일부개정법률안(대안)
# 양곡관리법 일부개정법률안(대안)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://news.kbs.co.kr/news/pc/main/main.html")


titles = driver.find_elements(By.CSS_SELECTOR, "div.box-contents div.txt-wrapper")

for title in titles :
    print(title.text.strip().replace('/n','').replace('\n',''))


driver.quit()
# Out:
# 김건희 여사, ‘피의자 신분’ 출석…이시각 특검 사무실주가조작부터 공천개입까지, 여러 의혹의 중심에 있는 김건희 여사가 특검에 출석해 조사를 받고 있습니다. 김 여사가 수사기관에 출석해 조사를 받는 건 이번이 처음인데요...
# “FTA, 안깨진 거 맞습니까?” …“다른 나라보다 유리”
# [단독] ‘주식 차명거래 의혹’ 이춘석 사건, 서울청 금융범죄수사대서 수사
# 민주당 ‘검찰 정상화 특위’ 출범 …중수청, 행안부 산하로
# 전국에 시간당 최대 50mm 국지성 호우 예보
# “신세계백화점 폭파” 범인은중학생…오늘 또 폭파 협박글
# 정부 “중국 단체 관광객에 ‘9월 29일~내년 6월 말’ 비자 면제”
# 해병특검, ‘이종섭 도피 의혹’ 외교부 압수수색
# 내란특검, ‘비화폰 관리’ 김대경 전 경호처 본부장 소환
# 휴가 떠난 이 대통령…정상회담 대비·광복절 특사고심도
# “추미애 법사위원장 내정”에 국민의힘 반응
# ‘대주주 기준’ 논란에…대통령실 “시장·소비자 반응 지켜보고 있어”
# “한달 수입 40만 원인데…” 아들 소득 많다고 수급탈락
# 트럼프 “가만안둬” 최후통첩에도 러시아·중국·인도…“어쩌라고”
# 부산항 역대 최대 규모 마약 적발…코카인 600kg 압수
# [영상] 美이민당국 ‘기습체포’ 한인 유학생…극적 석방에 ‘뜨거운 눈물’
# 충주시 인도에 2.5m 깊이 땅꺼짐…20대 여성 스스로 탈출
# 티몬, 영업재개 일정 연기…“회생절차 종결에 집중”
# ‘수사기관 사칭’ 4억 수표 가로채…보이스피싱 조직원 연달아 검거
# 알자지라 “이스라엘군, 가자지구 유엔 치료소 등 공습…18명 사망”
# 티몬, 영업재개 일정 연기…“회생절차 종결에 집중”
# 미 보건복지부, 7천억원 규모 mRNA 백신개발 계약 취소
# 환경장관, 가습기 살균제 피해자에게 사과…“제도 개선 추진”
# SKT, 대규모 해킹에 2분기 영업익 37% 급감…“보안 강화로 신뢰 회복”
# 이 대통령, 휴가지에서 ‘긴급 지시’…포스코이앤씨와 이춘석
# ...
