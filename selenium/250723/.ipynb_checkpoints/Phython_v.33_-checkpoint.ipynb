# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

# 웹 브라우저와 셀레니엄 버전을 일치시키는 것
# pip install webdriver-manager -> pip show webdriver-manager(설치 확인)

service = Service(ChromeDriverManager().install())
# 메서드 함수 사용, chromdirvermanager 설치하기
driver = webdriver.Chrome(service = service)
# driver => requests 역할 가능 / 인스턴스 객체 역할 O
driver.get("https://davelee-fun.github.io/")
assert "Teddy" in driver.title

time.sleep(2)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service = service)

driver.get("https://davelee-fun.github.io/")
#element = driver.find_element(By.TAG_NAME, "h1")
# find_element 특정 tag 하나 추출
# find_elements 다수의 tag 추출 후 list 정리
elements = driver.find_elements(By.ID, "navbarMediumish")
# text로 가져올 리터러블한 객체가 지정되지 않았기 때문에 text 함수 바로 사용X
for element in elements :
    print(element.text)



time.sleep(2)
driver.quit()
# Out:
# Blog
# About

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
# from selenium.webdriver.chrome.options import Options -> 옵션을 추가함

service = Service #("chromedriver 파일이 있는 주소창 + 역슬래쉬2번 \\ 크롬드라이버 파일이름")
# options = Options()
# options.add_argument("--disable-gpu") -> 옵션 중 그래픽 이미지값 끔, 충돌 요소를 일찍 없앰
# options.add_argument("--start-maxinized") -> 컴퓨터 옵션을 크롤링에 최적화
driver = webdriver.Chrome(service = service, # options = options) -> 옵션 넣기
# 로컬 / 현재 실행중 실제 크롬 브라우저 버전 다름 -> Error 가능성! -> driver 최신화
# chrome dirver 파일을 Service 객체로 가져온 후 드라이버 정의!

driver.get("https://davelee-fun.github.io/")
elements = driver.find_elements(By.ID, "navbarMediumish")
for element in elements :
    print(element.text)


time.sleep(2)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service = service)

driver.get("https://davelee-fun.github.io/")
# CSS 선택자, 부모 자식관계로 크롤링해옴
# element = driver.find_element(By.CSS_SELECTOR, "div.card-body > h4.card-text")
# .find_element(By.함수/선택자, "크롤링할 태그")
# elements = driver.find_elements(By.CSS_SELECTOR, "div.card-body > h4.card-text")
# 해당 속성 명으로 값을 찾아올 수 있음 ex)herf""

time.sleep(2)
driver.quit()
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service = service)

driver.get("https://davelee-fun.github.io/")
# 해당 속성 명으로 값을 찾아올 수 있음 ex)herf""

#element = driver.find_element(By.CSS_SELECTOR, "a.text-dark")
#print("text : ", element.text)
#print("driver.title : ", element.get_attribute("href"))
#print("get_attribute.class : ", element.get_attribute("class"))
#print("get_attribute.text : ", element.get_attribute("text"))

elements = driver.find_elements(By.CSS_SELECTOR, "a.text-dark")
for element in elements :
    print("text : ", element.text)
    print("driver.title : ", element.get_attribute("href"))
    print("get_attribute.class : ", element.get_attribute("class"))
    print("get_attribute.text : ", element.get_attribute("text"))
# 여려 요소를 뽑아 올때는 elements!

time.sleep(2)
driver.quit()
# Out:
# text :  매트리스커버 관련 상품 추천
# driver.title :  https://davelee-fun.github.io/product-83/
# get_attribute.class :  text-dark
# get_attribute.text :  매트리스커버 관련 상품 추천
# text :  여름이불세트 관련 상품 추천
# driver.title :  https://davelee-fun.github.io/product-69/
# get_attribute.class :  text-dark
# get_attribute.text :  여름이불세트 관련 상품 추천
# text :  행거도어 관련 상품 추천
# driver.title :  https://davelee-fun.github.io/product-20/
# get_attribute.class :  text-dark
# get_attribute.text :  행거도어 관련 상품 추천
# text :  매트리스커버 관련 상품 추천
# driver.title :  https://davelee-fun.github.io/product-105/
# get_attribute.class :  text-dark
# get_attribute.text :  매트리스커버 관련 상품 추천
# text :  매트리스커버 관련 상품 추천
# driver.title :  https://davelee-fun.github.io/product-99/
# get_attribute.class :  text-dark
# get_attribute.text :  매트리스커버 관련 상품 추천
# text :  매트리스커버 관련 상품 추천
# driver.title :  https://davelee-fun.github.io/product-98/
# get_attribute.class :  text-dark
# get_attribute.text :  매트리스커버 관련 상품 추천
# text :  매트리스커버 관련 상품 추천
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service = service)

driver.get("https://davelee-fun.github.io/")

element = driver.find_element(By.CSS_SELECTOR, "title")
print(element.text)
# head 안에 있는 타이틀 찾는 방법 diffence
print(element.get_attribute("text"))

time.sleep(2)
driver.quit()
# Out:
# Home | Teddy의 선물 블로그

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
driver = webdriver.Chrome(service = service)

driver.get("https://davelee-fun.github.io/")

driver.execute_script("window.scrollTo(0, document.body.scrollheigt )")
#driver.execute_script("return doucument.documentElement.scrollheigt")
#client_height = driver.execute_script("return document.documentElement.clientHeight")
#driver.execute_script("return document.documentElement.offsetheigt")
#print("clientheigt : ", client_height)

#driver.execute_async_script("window,scrillTo(0, document.body.scrollHeight )")
element = driver.find_element(By.NAME, "EMAIL")
element.clear()
element.send_keys("erro@error.com")


element.send_keys(Keys.RETURN)
time.sleep(2)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[3], line 21
#      14 #driver.execute_script("return doucument.documentElement.scrollheigt")
#      15 #client_height = driver.execute_script("return document.documentElement.clientHeight")
#      16 #driver.execute_script("return document.documentElement.offsetheigt")
#      17 #print("clientheigt : ", client_height)
#      18
#      19 #driver.execute_async_script("window,scrillTo(0, document.body.scrollHeight )")
#      20 element = driver.find_element(By.NAME, "EMAIL")
# ---> 21 element.clear()
#      22 element.send_keys("erro@error.com")
#      25 element.send_keys(Keys.RETURN)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:155, in WebElement.clear(self)
#     147 def clear(self) -> None:
#     148     """Clears the text if it's a text entry element.
#     149
#     150     Example:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("--disable-gpu")
options.add_argument("lang=ko_KR")


driver = webdriver.Chrome(service = service, options = options)
driver.get("https://davelee-fun.github.io/")

element = driver.find_element(By.TAG_NAME, "h1")
print(element.text)



time.sleep(2)
driver.quit()
# Out:
# Teddy의 선물 블로그

# %%
class = course = dev_course_list 자식요소 class course

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("--disable-gpu")
options.add_argument("lang=ko_KR")


driver = webdriver.Chrome(service = service, options = options)
driver.get("https://crawlingtest.netlify.app/")

element = driver.find_elements(By.CSS_SELECTOR, "ul#dev_course_list .course")
for elements in element :
    print(elements.text)



time.sleep(2)
driver.quit()
# Out:
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
커리큘럼 일정 표 안에 이쓴ㄴ 데이터 모두 추출

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("--disable-gpu")
options.add_argument("lang=ko_KR")


driver = webdriver.Chrome(service = service, options = options)
driver.get("https://crawlingtest.netlify.app/")

element = driver.find_elements(By.TAG_NAME, "tr")
for elements in element :
    print(elements.text)



time.sleep(2)
driver.quit()
# Out:
# 일정 커리큘럼 타이틀 난이도
# 5.1 ~ 6.15 나만의 엣지있는 블로그 사이트 만들기 (취미로 익히는 IT) 초급
# 6.16 ~ 7.31 파이썬과 데이터과학 첫걸음 (IT 기본기 익히기) 중급

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("--disable-gpu")
options.add_argument("lang=ko_KR")


driver = webdriver.Chrome(service = service, options = options)
driver.get("https://crawlingtest.netlify.app/")

element = driver.find_elements(By.CSS_SELECTOR, "ul#dev_course_list li.course")
print(element[8].text)

print("k")

time.sleep(2)
driver.quit()
# Out:
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]
# k

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("--disable-gpu")
options.add_argument("lang=ko_KR")


driver = webdriver.Chrome(service = service, options = options)
driver.get("https://divjason.github.io/sellenium-test/")

element = driver.find_element(By.CSS_SELECTOR, "span.news")
print(element.text)
ㅉ

time.sleep(2)
driver.quit()
# Out:
# 뉴스: 머신러닝 강좌가 나왔어요~~~
# k

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("--disable-gpu")
options.add_argument("lang=ko_KR")


driver = webdriver.Chrome(service = service, options = options)
driver.get("https://divjason.github.io/sellenium-test/")

element = driver.find_element(By.CSS_SELECTOR, "span.news")
print(element.text)
ㅉ

time.sleep(2)
driver.quit()

# %%
imput 태그 요소 아이디 error.errp.com 비밀번호 1234 입력 후 로그인 버튼 크릭

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

service = Service(ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service = service, options = options)
driver.get("https://divjason.github.io/sellenium-test/")

search_input1 = driver.find_element(By.CSS_SELECTOR, "input#username")
search_input1.clear()
search_input1.send_keys("error@error.com")
search_input2 = driver.find_element(By.CSS_SELECTOR, "input#password")
search_input2.clear()
search_input2.send_keys("1234")
# search_input2.send_keys(Keys.RETURN)

element01 = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
element01.click()

time.sleep(3)

element02 = driver.find_element(By.CSS_SELECTOR, "div.message")
print(element02.text)
element03 = driver.find_element(By.CSS_SELECTOR, "input[type='submit']")
element03.click()
search_input1 = driver.find_element(By.CSS_SELECTOR, "input#username")
search_input1.clear()
search_input1.send_keys("error@error.com")
search_input2 = driver.find_element(By.CSS_SELECTOR, "input#password")
search_input2.clear()
search_input2.send_keys("1234")

time.sleep(10)

driver.quit()
# Out:
# 실제 사이트는 https://megaitlab.com/ 입니다
# 본 페이지는 로그인된 페이지입니다!
# 뉴스: 머신러닝 강좌가 나왔어요~~~
