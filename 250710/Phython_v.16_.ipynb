# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
data = BeautifulSoup(res.content,"html.parser")

find_data = data.find_all("li", class_="course")
for item in find_data :
    for item1 in item :
        print(item1.get_text())
# Out:
# (왕초보) - 클래스 소개
#
#
#
#
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
#
#
#
#
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
#
#
#
#
# (왕초보) - 초간단 페이지 만들어보기
#
#
#
#
# (왕초보) - 이쁘게 테마 적용해보기
#
#
#
#
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#
#
#
#
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#
#
#
#
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
#
#
#
#
# (초급) - 필요한 프로그램 설치 시연 [5]
#
#
#
#
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
#
#
#
#
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
#
#
#
#
# (초급) -     나대신 주기적으로 파이썬 프로그램
#           실행하기 [7]
#
#
#
#
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
#
#
#
#
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
#           [12]
#
#
#
#
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
#
#
#
#
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버
#           블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
data = BeautifulSoup(res.content,"html.parser")

find_data = data.find_all("ul", attrs = {"id" : "hobby_course_list"})
for item in find_data :
    for item1 in item :
        print(item1.get_text())

find_data = data.find("ul", id = "hobby_course_list").find_all("li", "course")
for datas in data :
    print(datas.get_text())
    
#파이썬을 활용해 특정 웹사이트 내 요소 크롤링, 해당 값 자료형태 > 객체의 형태
# => 개체 속성 혹은 메서드 함수 사용
# Out:
# (왕초보) - 클래스 소개
#
#
#
#
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
#
#
#
#
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
#
#
#
#
# (왕초보) - 초간단 페이지 만들어보기
#
#
#
#
# (왕초보) - 이쁘게 테마 적용해보기
#
#
#
#
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#
#
#
#
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#
#
#
#
#
#
#
#
#
#
# Document
#
#
# 메가스터디 크롤링 테스트 페이지
# 나만의 엣지있는 블로그 사이트 만들기
#
#
# (왕초보) - 클래스 소개
#
#
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
#
#
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
#
#
# (왕초보) - 초간단 페이지 만들어보기
#
#
# (왕초보) - 이쁘게 테마 적용해보기
#
#
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지
#           만들기
#
#
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지
#           꾸며보기
#
#
#
#       당신의 커리어에 파이썬을 입히세요! 자신만의 자동 프로그램까지 가져가는
#       특별한 강의
#
#
#
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
#
#
# (초급) - 필요한 프로그램 설치 시연 [5]
#
#
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
#
#
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
#
#
# (초급) -     나대신 주기적으로 파이썬 프로그램
#           실행하기 [7]
#
#
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
#
#
# ...

# %%
### 파이썬 크롤링 미션
- 해당 사이트에서 course라는 클래스값을 갖고 있는 li테그 내부 텍스트를 출력하세요
단, 설명 문헌만 찾음, -와 같은 부가적인 설명은 제외, 실제 해당 과정의 설명문만 크롤링

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
data = BeautifulSoup(res.content,"html.parser")

find_data = data.find_all("li", attrs = {"class" : "course"})
for item in find_data :
    for item1 in item :
        print(item1.split("-")[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       8 for item in find_data :
#       9     for item1 in item :
# ---> 10         print(item1.split("-")[0])
#
# TypeError: 'NoneType' object is not callable

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
data = BeautifulSoup(res.content,"html.parser")

find_data = data.find_all("li", attrs = {"class" : "course"})
for index, item in enumerate(find_data) :
   print(index + 1, item.get_text().split("-")[1].replace("\n", " ").replace(" ","").split("[")[0].strip())

#get_text() => 자료를 str class로 가져옴
# Out:
# 1 클래스소개
# 2 블로그개발필요한준비물준비하기
# 3 Githubpages설정해서블로그첫페이지만들어보기
# 4 초간단페이지만들어보기
# 5 이쁘게테마적용해보기
# 6 마크다운기초이해하고,실제나만의블로그페이지만들기
# 7 다양한마크다운기법익혀보며,나만의블로그페이지꾸며보기
# 8 강사가실제사용하는자동프로그램소개
# 9 필요한프로그램설치시연
# 10 데이터를엑셀파일로만들기
# 11 엑셀파일이쁘게!이쁘게!
# 12 나대신주기적으로파이썬프로그램실행하기
# 13 파이썬으로슬랙(slack)메신저에글쓰기
# 14 웹사이트변경사항주기적으로체크해서,메신저로알람주기
# 15 네이버API사용해서,블로그에글쓰기
# 16 자동으로쿠팡파트너스API로가져온상품정보,네이버블로그/트위터에홍보하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://crawlingtest.netlify.app/")
data = BeautifulSoup(res.content,"html.parser")

find_data = data.find_all("li", attrs = {"class" : "course"})
